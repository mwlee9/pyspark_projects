# %%
pip install meteostat
# Out:
# Requirement already satisfied: meteostat in /opt/venv/lib/python3.7/site-packages (1.1.1)
# Requirement already satisfied: pandas>=1.1 in /opt/venv/lib/python3.7/site-packages (from meteostat) (1.2.2)
# Requirement already satisfied: pytz in /opt/venv/lib/python3.7/site-packages (from meteostat) (2021.1)
# Requirement already satisfied: numpy in /opt/venv/lib/python3.7/site-packages (from meteostat) (1.20.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /opt/venv/lib/python3.7/site-packages (from pandas>=1.1->meteostat) (2.8.1)
# Requirement already satisfied: six>=1.5 in /opt/venv/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas>=1.1->meteostat) (1.15.0)
# WARNING: You are using pip version 19.2.3, however version 21.0.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno
import numpy as np

# %%
from pyspark import SparkConf
from pyspark.sql import SparkSession
from pyspark.sql import functions as f
from pyspark.sql import types

# %%
spark = SparkSession.builder.getOrCreate()

# %%
# Import Meteostat library and dependencies
from datetime import datetime
import matplotlib.pyplot as plt
from meteostat import Point, Daily

# Set time period
start = datetime(1990, 1, 1)
end = datetime(2020, 12, 31)

# Create Point for Vancouver, BC
vancouver = Point(49.2497, -123.1193, 70)

# Get daily data for 2018
data = Daily(vancouver, start, end)
data = data.fetch()

# Plot line chart including average, minimum and maximum temperature
data.plot(y=['tavg', 'tmin', 'tmax'])
plt.show()

# %%
df = spark.read.csv('./DATA/*.csv', inferSchema=True, header=True)

# %%
# df.write.format('parquet').mode('overwrite').option('compression','snappy').save('./DATA/yellow_tripdata_2019-02')
df.write.parquet('./DATA/yellow_tripdata_2019-02', compression='snappy', mode='overwrite')

# %%
df = spark.read.parquet('./DATA/PARQUET')

# %% [markdown]
# ### Initial Inspection

# %% [markdown]
# #### Print a few rows

# %%
df.show()
# Out:
# +--------+--------------------+---------------------+---------------+-------------+----------+------------------+------------+------------+------------+-----------+-----+-------+----------+------------+---------------------+------------+--------------------+
# |VendorID|tpep_pickup_datetime|tpep_dropoff_datetime|passenger_count|trip_distance|RatecodeID|store_and_fwd_flag|PULocationID|DOLocationID|payment_type|fare_amount|extra|mta_tax|tip_amount|tolls_amount|improvement_surcharge|total_amount|congestion_surcharge|
# +--------+--------------------+---------------------+---------------+-------------+----------+------------------+------------+------------+------------+-----------+-----+-------+----------+------------+---------------------+------------+--------------------+
# |       1| 2019-01-01 00:46:40|  2019-01-01 00:53:20|              1|          1.5|         1|                 N|         151|         239|           1|        7.0|  0.5|    0.5|      1.65|         0.0|                  0.3|        9.95|                null|
# |       1| 2019-01-01 00:59:47|  2019-01-01 01:18:59|              1|          2.6|         1|                 N|         239|         246|           1|       14.0|  0.5|    0.5|       1.0|         0.0|                  0.3|        16.3|                null|
# |       2| 2018-12-21 13:48:30|  2018-12-21 13:52:40|              3|          0.0|         1|                 N|         236|         236|           1|        4.5|  0.5|    0.5|       0.0|         0.0|                  0.3|         5.8|                null|
# |       2| 2018-11-28 15:52:25|  2018-11-28 15:55:45|              5|          0.0|         1|                 N|         193|         193|           2|        3.5|  0.5|    0.5|       0.0|         0.0|                  0.3|        7.55|                null|
# |       2| 2018-11-28 15:56:57|  2018-11-28 15:58:33|              5|          0.0|         2|                 N|         193|         193|           2|       52.0|  0.0|    0.5|       0.0|         0.0|                  0.3|       55.55|                null|
# |       2| 2018-11-28 16:25:49|  2018-11-28 16:28:26|              5|          0.0|         1|                 N|         193|         193|           2|        3.5|  0.5|    0.5|       0.0|        5.76|                  0.3|       13.31|                null|
# |       2| 2018-11-28 16:29:37|  2018-11-28 16:33:43|              5|          0.0|         2|                 N|         193|         193|           2|       52.0|  0.0|    0.5|       0.0|         0.0|                  0.3|       55.55|                null|
# |       1| 2019-01-01 00:21:28|  2019-01-01 00:28:37|              1|          1.3|         1|                 N|         163|         229|           1|        6.5|  0.5|    0.5|      1.25|         0.0|                  0.3|        9.05|                null|
# |       1| 2019-01-01 00:32:01|  2019-01-01 00:45:39|              1|          3.7|         1|                 N|         229|           7|           1|       13.5|  0.5|    0.5|       3.7|         0.0|                  0.3|        18.5|                null|
# |       1| 2019-01-01 00:57:32|  2019-01-01 01:09:32|              2|          2.1|         1|                 N|         141|         234|           1|       10.0|  0.5|    0.5|       1.7|         0.0|                  0.3|        13.0|                null|
# |       1| 2019-01-01 00:24:04|  2019-01-01 00:47:06|              2|          2.8|         1|                 N|         246|         162|           1|       15.0|  0.5|    0.5|      3.25|         0.0|                  0.3|       19.55|                null|
# |       1| 2019-01-01 00:21:59|  2019-01-01 00:28:24|              1|          0.7|         1|                 N|         238|         151|           1|        5.5|  0.5|    0.5|       1.7|         0.0|                  0.3|         8.5|                null|
# |       1| 2019-01-01 00:45:21|  2019-01-01 01:31:05|              1|          8.7|         1|                 N|         163|          25|           1|       34.5|  0.5|    0.5|      7.15|         0.0|                  0.3|       42.95|                null|
# |       1| 2019-01-01 00:43:19|  2019-01-01 01:07:42|              1|          6.3|         1|                 N|         224|          25|           1|       21.5|  0.5|    0.5|       5.7|         0.0|                  0.3|        28.5|                null|
# |       1| 2019-01-01 00:58:24|  2019-01-01 01:15:18|              1|          2.7|         1|                 N|         141|         234|           1|       13.0|  0.5|    0.5|       1.0|         0.0|                  0.3|        15.3|                null|
# |       2| 2019-01-01 00:23:14|  2019-01-01 00:25:40|              1|         0.38|         1|                 N|         170|         170|           2|        3.5|  0.5|    0.5|       0.0|         0.0|                  0.3|         4.8|                null|
# |       2| 2019-01-01 00:39:51|  2019-01-01 00:48:02|              1|         0.55|         1|                 N|         170|         170|           1|        6.5|  0.5|    0.5|      1.95|         0.0|                  0.3|        9.75|                null|
# |       2| 2019-01-01 00:46:00|  2019-01-01 00:49:07|              1|          0.3|         1|                 N|         107|         107|           1|        4.0|  0.5|    0.5|      1.06|         0.0|                  0.3|        6.36|                null|
# |       2| 2019-01-01 00:57:45|  2019-01-01 01:03:51|              1|         1.42|         1|                 N|         170|         141|           1|        6.5|  0.5|    0.5|      1.56|         0.0|                  0.3|        9.36|                null|
# |       2| 2019-01-01 00:16:16|  2019-01-01 00:25:57|              1|         1.72|         1|                 N|          41|         247|           2|        9.0|  0.5|    0.5|       0.0|         0.0|                  0.3|        10.3|                null|
# +--------+--------------------+---------------------+---------------+-------------+----------+------------------+------------+------------+------------+-----------+-----+-------+----------+------------+---------------------+------------+--------------------+
# only showing top 20 rows

# %% [markdown]
# #### Print Dtypes/Schema

# %%
df.printSchema()
# Out:
# root
#  |-- VendorID: integer (nullable = true)
#  |-- tpep_pickup_datetime: string (nullable = true)
#  |-- tpep_dropoff_datetime: string (nullable = true)
#  |-- passenger_count: integer (nullable = true)
#  |-- trip_distance: double (nullable = true)
#  |-- RatecodeID: integer (nullable = true)
#  |-- store_and_fwd_flag: string (nullable = true)
#  |-- PULocationID: integer (nullable = true)
#  |-- DOLocationID: integer (nullable = true)
#  |-- payment_type: integer (nullable = true)
#  |-- fare_amount: double (nullable = true)
#  |-- extra: double (nullable = true)
#  |-- mta_tax: double (nullable = true)
#  |-- tip_amount: double (nullable = true)
#  |-- tolls_amount: double (nullable = true)
#  |-- improvement_surcharge: double (nullable = true)
#  |-- total_amount: double (nullable = true)
#  |-- congestion_surcharge: double (nullable = true)

# %% [markdown]
# #### Get a count of the number of rows and columns

# %%
df.count(),len(df.columns)
# Out:
# (7667792, 18)

# %% [markdown]
# #### Get Summary Stats

# %%
df_samp = df.sample(fraction=.1, seed=.42)

# %%
df_samp.count()
# Out:
# 767448

# %%
df_samp.summary().show()
# Out:
# +-------+------------------+--------------------+---------------------+------------------+-----------------+------------------+------------------+------------------+------------------+-------------------+------------------+------------------+-------------------+------------------+-------------------+---------------------+------------------+--------------------+
# |summary|          VendorID|tpep_pickup_datetime|tpep_dropoff_datetime|   passenger_count|    trip_distance|        RatecodeID|store_and_fwd_flag|      PULocationID|      DOLocationID|       payment_type|       fare_amount|             extra|            mta_tax|        tip_amount|       tolls_amount|improvement_surcharge|      total_amount|congestion_surcharge|
# +-------+------------------+--------------------+---------------------+------------------+-----------------+------------------+------------------+------------------+------------------+-------------------+------------------+------------------+-------------------+------------------+-------------------+---------------------+------------------+--------------------+
# |  count|            767448|              767448|               767448|            767448|           767448|            767448|            767448|            767448|            767448|             767448|            767448|            767448|             767448|            767448|             767448|               767448|            767448|              281306|
# |   mean|1.6369330560507032|                null|                 null|1.5679629108421678|2.801805360102587|1.0587114697021818|              null|165.54252665978672|163.85180233709644| 1.2914555774462895|12.869785105961581|0.3284399464198226| 0.4968542103178326|1.8305437241350295|0.31727190637021013|   0.2993428870754887|16.146746854512255|6.220983555274327E-5|
# | stddev|0.5408370214822305|                null|                 null| 1.224905878934274|3.716162619251098| 0.694552226993265|              null| 66.37447338405251| 70.39788845672994|0.47278912925639327| 412.0952058650036|0.7708197646974831|0.04480279811212524|2.4943287904990723| 1.6038269613508156| 0.019009264657570045| 412.7748433447155|0.012470816800541202|
# |    min|                 1| 2008-12-31 23:03:13|  2008-12-31 23:17:47|                 0|              0.0|                 1|                 N|                 1|                 1|                  1|            -284.0|              -4.5|               -0.5|              -8.8|              -5.76|                 -0.3|            -284.8|                 0.0|
# |    25%|                 1|                null|                 null|                 1|              0.9|                 1|              null|               132|               113|                  1|               6.0|               0.0|                0.5|               0.0|                0.0|                  0.3|              8.19|                 0.0|
# |    50%|                 2|                null|                 null|                 1|             1.52|                 1|              null|               162|               162|                  1|               8.5|               0.0|                0.5|              1.44|                0.0|                  0.3|             11.27|                 0.0|
# |    75%|                 2|                null|                 null|                 2|              2.8|                 1|              null|               234|               234|                  2|              13.5|               0.5|                0.5|              2.34|                0.0|                  0.3|             16.56|                 0.0|
# |    max|                 4| 2019-03-19 02:57:22|  2019-03-19 10:04:31|                 9|           123.42|                99|                 Y|               265|               265|                  4|         355676.98|            535.38|               2.42|             400.0|             576.47|                  0.3|         356214.78|                 2.5|
# +-------+------------------+--------------------+---------------------+------------------+-----------------+------------------+------------------+------------------+------------------+-------------------+------------------+------------------+-------------------+------------------+-------------------+---------------------+------------------+--------------------+

# %% [markdown]
# ### Remove Duplicate Rows

# %%
df_d = df.distinct()

# %% [markdown]
# ### Get Summary of data

# %%
df_d.summary().show()

# %% [markdown]
# ### Check how many unique values per column

# %%
pd_df = df.toPandas()

# %%
pd_df.nunique()

# %%
msno.

# %%
list_of_nunique = [f.countDistinct(c) for c in df_d.columns]
df_d.select(list_of_nunique).show()

# %% [markdown]
# ### Validate columns that have bad data

# %%
df_d.select('ca').distinct().show()

# %%
df_d.groupBy('ca').count().show()

# %%
df_d.where(f.col('ca') == '?').show()

# %%
df_d = df_d.replace("?", None, subset = "ca")
df_d.groupby('ca').count().show()

# %%
df_d = df_d.replace("?",None,subset="thal")
df_d.groupby("thal").count().show()

# %% [markdown]
# ### Find Null counts

# %% [markdown]
# #### List Comprehension

# %%
list_col = [f.count(f.when(f.col(c).isNull(),c)).alias(c) for c in df_d.columns]

df_d.select(list_col).show()

# %% [markdown]
# #### Map

# %%
def get_null_cnt(c):
    return f.count(f.when(f.col(c).isNull(),c)).alias(c)

map_of_nulls = map(get_null_cnt, df_d.columns )
list_null_cnt = list(map_of_nulls)

df_d.select(list_null_cnt).show()

# %% [markdown]
# ### Get condition counts for all columns: check 0 values

# %%
def get_null_cnt(c):
    return f.count(f.when(f.col(c) == '0',c)).alias(c)

map_of_nulls = map(get_null_cnt, df_d.columns )
list_null_cnt = list(map_of_nulls)

df_d.select(list_null_cnt).show()

# %% [markdown]
# ### Fill nulls with Median

# %%
df_d = df_d.withColumn('ca', f.col('ca').cast(types.IntegerType()))

ca_median = df_d.approxQuantile("ca", [0.5], 0.25)

df_d = df_d.na.fill(ca_median[0])

########################################

df_d = df_d.withColumn('thal', f.col('thal').cast(types.IntegerType()))

thal_median = df_d.approxQuantile("thal", [0.5], 0.25)

df_d = df_d.na.fill(thal_median[0])

########################################

list_col = [f.count(f.when(f.col(c).isNull(),c)).alias(c) for c in df_d.columns]

df_d.select(list_col).show()

# %% [markdown]
# ### Get Mean for filling

# %%
df_d.select('ca').agg(f.avg("ca")).collect()[0][0]

# df_d = df_d.replace(None,f.mean())

# %% [markdown]
# ### Get summary again

# %%
df_d.describe().show()

# %% [markdown]
# ### Replace features with names for easier to understand plots

# %%
df_p = df_d

df_p = df_p.withColumn('target',f.col('num').cast("string"))
df_p = df_p.replace(['1','2','3','4'],"Disease", subset='target')
df_p = df_p.replace('0',"No_Disease", subset='target')

df_p = df_p.withColumn('sex',f.col('sex').cast('string'))
df_p = df_p.replace({'1.0': "Male", '0.0': "Female"}, subset='sex')

df_p = df_p.withColumn('cp', f.col('cp').cast('string'))
df_p = df_p.replace({'2.0': "atypical_angina", '1.0': 'typical_angina', '3.0': 'non-anginal pain', '4.0': 'asymptomatic'},
            subset='cp')

df_p = df_p.withColumn('exang', f.col('exang').cast('string'))
df_p = df_p.replace({'0.0': 'True', '1.0': 'False'}, subset = 'exang')

df_p = df_p.withColumn('fbs', f.col('fbs').cast('string'))
df_p = df_p.replace({'0.0': 'True', '1.0': 'False'}, subset = 'fbs')

df_p = df_p.withColumn('slope', f.col('slope').cast('string'))
df_p = df_p.replace({'1.0': 'upsloping', '2.0': 'flat', '3.0': 'downsloping'}, subset = 'slope')

df_p = df_p.withColumn('thal', f.col('thal').cast('string'))
df_p = df_p.replace({'3': 'fixed_defect', '6': 'fixed_defect', '7': "reversable_defect"}, subset = 'thal')

df_p.show()

df_p.dtypes

# %% [markdown]
# ### Find Outliers

# %%
pd_df = df_d.toPandas()

# %%
pd_df.plot(kind='box', subplots='True',layout=(2,7),sharex=False,sharey=False, figsize=(20, 10))

# %%
# fig = px.box(pd_df, x='target', y='chol')
# fig.show()

# %%
pd_df = df_p.toPandas()
sns.boxplot(x='target',y='chol',data=pd_df,width=1)

# %% [markdown]
# #### Create the IQR bounds
# https://blog.zhaytam.com/2019/07/15/outliers-detection-in-pyspark-2-interquartile-range/

# %%
## demonstrate Zip an list comprehensions. Curly's used for dictionary, c is first element : second element
## in this case the second element is going to be a list of the bounds calculated by approxQuantile.
## Use if statements to get only the numerical datatypes
{c: d for c,d in zip(df_p.columns,df_p.dtypes) if (d[1] == 'double' or d[1] == 'int') }

# %%
### Dictionary Method: create a dictionary of dictionaries for nested addressing later. More complex but better
### Var naming
dict_bounds = {c: dict(zip(['q1','q3'],df_p.approxQuantile(c,[0.25,.75],0)))
          for c,d in zip(df_p.columns,df_p.dtypes) if (d[1] == 'double' or d[1] == 'int') }
dict_bounds

# %%
for c in dict_bounds:
    iqr = dict_bounds[c]['q3'] - dict_bounds[c]['q1']
    dict_bounds[c]['min'] = dict_bounds[c]['q1'] - iqr*1.5
    dict_bounds[c]['max'] = dict_bounds[c]['q3'] + iqr*1.5
    
dict_bounds

# %% [markdown]
# #### Apply bounds and create new column with outliers flagged

# %%
for c in dict_bounds:
    df_p = df_p.withColumn(c+'_outlier', f.when(
        ~f.col(c).between(dict_bounds[c]['min'], dict_bounds[c]['max']), 'True')
                .otherwise('False'))

df_p.show()

# %% [markdown]
# #### Verify Outliers

# %%
df_p.select('*').where(f.col('chol_outlier') == True).show()

# %% [markdown]
# #### Count and Remove Outliers

# %%
{c: df_p.where(f.col(c) == True).count() for c in df_p.columns if c[-7:] == 'outlier'}

# %%
df_nout = df_p.select('*').where(
    (f.col('age_outlier') == False)
    & (f.col("trestbps_outlier") == False)
    & (f.col("chol_outlier") == False)
    & (f.col("restecg_outlier") == False)
    & (f.col("thalach_outlier") == False)
    & (f.col("oldpeak_outlier") == False)
    & (f.col("ca_outlier") == False)
    & (f.col("num_outlier") == False)
    )
df_nout.show()
