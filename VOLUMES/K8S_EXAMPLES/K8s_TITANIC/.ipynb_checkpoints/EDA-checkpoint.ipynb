# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from pyspark.sql import SparkSession
from pyspark.sql import functions as f

# %%
spark = SparkSession.builder.config('spark.shuffle.file.buffer','1m')\
    .config('spark.sql.adaptive.enabled','true')\
    .getOrCreate()

# %%
train_df = spark.read.csv('train.csv', header=True, inferSchema=True)
test_df = spark.read.csv('test.csv', header=True, inferSchema=True)

# %% [markdown]
# pclass: A proxy for socio-economic status (SES)
# 1st = Upper
# 2nd = Middle
# 3rd = Lower
#
# age: Age is fractional if less than 1. If the age is estimated, is it in the form of xx.5
#
# sibsp: The dataset defines family relations in this way...
# Sibling = brother, sister, stepbrother, stepsister
# Spouse = husband, wife (mistresses and fiancés were ignored)
#
# parch: The dataset defines family relations in this way...
# Parent = mother, father
# Child = daughter, son, stepdaughter, stepson
# Some children travelled only with a nanny, therefore parch=0 for them.

# %% [markdown]
# # Profile and Describe Data
# ## Summarize and get shape

# %%
train_df.show(5)
# Out:
# +-----------+--------+------+--------------------+------+----+-----+-----+----------------+-------+-----+--------+
# |PassengerId|Survived|Pclass|                Name|   Sex| Age|SibSp|Parch|          Ticket|   Fare|Cabin|Embarked|
# +-----------+--------+------+--------------------+------+----+-----+-----+----------------+-------+-----+--------+
# |          1|       0|     3|Braund, Mr. Owen ...|  male|22.0|    1|    0|       A/5 21171|   7.25| null|       S|
# |          2|       1|     1|Cumings, Mrs. Joh...|female|38.0|    1|    0|        PC 17599|71.2833|  C85|       C|
# |          3|       1|     3|Heikkinen, Miss. ...|female|26.0|    0|    0|STON/O2. 3101282|  7.925| null|       S|
# |          4|       1|     1|Futrelle, Mrs. Ja...|female|35.0|    1|    0|          113803|   53.1| C123|       S|
# |          5|       0|     3|Allen, Mr. Willia...|  male|35.0|    0|    0|          373450|   8.05| null|       S|
# +-----------+--------+------+--------------------+------+----+-----+-----+----------------+-------+-----+--------+
# only showing top 5 rows

# %%
train_df.dtypes
# Out:
# [('PassengerId', 'int'),
#  ('Survived', 'int'),
#  ('Pclass', 'int'),
#  ('Name', 'string'),
#  ('Sex', 'string'),
#  ('Age', 'double'),
#  ('SibSp', 'int'),
#  ('Parch', 'int'),
#  ('Ticket', 'string'),
#  ('Fare', 'double'),
#  ('Cabin', 'string'),
#  ('Embarked', 'string')]

# %%
train_df.describe().show()
# Out:
# +-------+-----------------+-------------------+------------------+--------------------+------+------------------+------------------+-------------------+------------------+-----------------+-----+--------+
# |summary|      PassengerId|           Survived|            Pclass|                Name|   Sex|               Age|             SibSp|              Parch|            Ticket|             Fare|Cabin|Embarked|
# +-------+-----------------+-------------------+------------------+--------------------+------+------------------+------------------+-------------------+------------------+-----------------+-----+--------+
# |  count|              891|                891|               891|                 891|   891|               714|               891|                891|               891|              891|  204|     889|
# |   mean|            446.0| 0.3838383838383838| 2.308641975308642|                null|  null| 29.69911764705882|0.5230078563411896|0.38159371492704824|260318.54916792738| 32.2042079685746| null|    null|
# | stddev|257.3538420152301|0.48659245426485753|0.8360712409770491|                null|  null|14.526497332334035|1.1027434322934315| 0.8060572211299488|471609.26868834975|49.69342859718089| null|    null|
# |    min|                1|                  0|                 1|"Andersson, Mr. A...|female|              0.42|                 0|                  0|            110152|              0.0|  A10|       C|
# |    max|              891|                  1|                 3|van Melkebeke, Mr...|  male|              80.0|                 8|                  6|         WE/P 5735|         512.3292|    T|       S|
# +-------+-----------------+-------------------+------------------+--------------------+------+------------------+------------------+-------------------+------------------+-----------------+-----+--------+

# %% [markdown]
# ### Check for # of unique vals

# %%
train_df.select('survived').distinct().show()
# Out:
# +--------+
# |survived|
# +--------+
# |       1|
# |       0|
# +--------+

# %%
{c: train_df.select(c).distinct().count() for c in train_df.columns}
# Out:
# {'PassengerId': 891,
#  'Survived': 2,
#  'Pclass': 3,
#  'Name': 891,
#  'Sex': 2,
#  'Age': 89,
#  'SibSp': 7,
#  'Parch': 7,
#  'Ticket': 681,
#  'Fare': 248,
#  'Cabin': 148,
#  'Embarked': 4}

# %%
# {c: train_df.select(c).distinct().show() for c in train_df.columns}

# %%
### Get Nulls
print('# of Nulls:')
{c: train_df.select(c).where(f.col(c).isNull()).count() for c in train_df.columns}
# Out:
# # of Nulls:
# {'PassengerId': 0,
#  'Survived': 0,
#  'Pclass': 0,
#  'Name': 0,
#  'Sex': 0,
#  'Age': 177,
#  'SibSp': 0,
#  'Parch': 0,
#  'Ticket': 0,
#  'Fare': 0,
#  'Cabin': 687,
#  'Embarked': 2}

# %% [markdown]
# # Process Data

# %% [markdown]
# ## Remove Duplicates

# %%
dt_df = train_df.distinct()

# %% [markdown]
# ## Fill na

# %%
print("# of Nulls in Age:")
print(dt_df.select('Age').filter('Age IS NULL').count())
# dt_df.select('Age').where(f.col('Age').isNull()).show()
# dt_df.select('Age').where(dt_df['Age'].isNull()).show()
# Out:
# # of Nulls in Age:
# 177

# %%
### Get Median Age
med_age = dt_df.approxQuantile('Age',[0.5],0)[0]
# ave_age = dt_df.groupBy().agg({'Age': 'mean'})
ave_age = dt_df.groupby().mean('Age').first()[0]
# ave_age = dt_df.select(f.mean('Age'))

print(med_age,ave_age)
# Out:
# 28.0 29.69911764705882

# %%
dt_df = dt_df.withColumn('ageImputed', f.when(f.col('Age').isNull(),'1').otherwise(0))

# %%
dt_df_nna = dt_df.na.fill(med_age, subset='Age')

# %%
# dt_df_nna.select('*').filter('Age IS NULL').show()
# dt_df_nna.select('*').filter(f.expr('Age IS NULL')).show()
dt_df_nna.select('*').filter(f.col('Age').isNull()).show()
dt_df_nna.select('*').show()
dt_df.select('*').show()
# Out:
# +-----------+--------+------+----+---+---+-----+-----+------+----+-----+--------

# |         11|       1|     3|Sandstrom, Miss. ...|female| 4.0|    1|    1|           PP 9549|   16.7|     G6|       S|         0|
# |         71|       0|     2|Jenkin, Mr. Steph...|  male|32.0|    0|    0|        C.A. 33111|   10.5|   null|       S|         0|
# |        266|       0|     2|   Reeves, Mr. David|  male|36.0|    0|    0|        C.A. 17248|   10.5|   null|       S|         0|
# |        281|       0|     3|    Duane, Mr. Frank|  male|65.0|    0|    0|            336439|   7.75|   null|       Q|         0|
# |        472|       0|     3|     Cacic, Mr. Luka|  male|38.0|    0|    0|            315089| 8.6625|   null|       S|         0|
# |        615|       0|     3|Brocklebank, Mr. ...|  male|35.0|    0|    0|            364512|   8.05|   null|       S|         0|
# |        701|       1|     1|Astor, Mrs. John ...|female|18.0|    1|    0|          PC 17757|227.525|C62 C64|       C|         0|
# |        706|       0|     2|"Morley, Mr. Henr...|  male|39.0|    0|    0|            250655|   26.0|   null|       S|         0|
# |        158|       0|     3|     Corn, Mr. Harry|  male|30.0|    0|    0|   SOTON/OQ 392090|   8.05|   null|       S|         0|
# |        189|       0|     3|    Bourke, Mr. John|  male|40.0|    1|    1|            364849|   15.5|   null|       Q|         0|
# |        345|       0|     2|Fox, Mr. Stanley ...|  male|36.0|    0|    0|            229236|   13.0|   null|       S|         0|
# |        398|       0|     2|McKane, Mr. Peter...|  male|46.0|    0|    0|             28403|   26.0|   null|       S|         0|
# +-----------+--------+------+--------------------+------+----+-----+-----+------------------+-------+-------+--------+----------+
# only showing top 20 rows

# %%
### Impute source, dest
# dt_df_nna.groupby('embarked').max().show() # Show's max for each group among all columns
# dt_df_nna.groupby('embarked').count().agg({'embarked':'max'}).first()[0]
comm_embark = dt_df_nna.groupby('embarked').count().agg({'embarked':'max'}).select('*').first()[0][0]

dt_df_nna = dt_df_nna.withColumn('embarkedImputed', f.when(dt_df_nna['embarked'].isNull(), 1).otherwise(0))

dt_df_nnae = dt_df_nna.na.fill(comm_embark) 

dt_df_nnae.where(f.col('embarkedImputed') == 1).show()
# Out:
# +-----------+--------+------+--------------------+------+----+-----+-----+------+----+-----+--------+----------+---------------+
# |PassengerId|Survived|Pclass|                Name|   Sex| Age|SibSp|Parch|Ticket|Fare|Cabin|Embarked|ageImputed|embarkedImputed|
# +-----------+--------+------+--------------------+------+----+-----+-----+------+----+-----+--------+----------+---------------+
# |         62|       1|     1| Icard, Miss. Amelie|female|38.0|    0|    0|113572|80.0|  B28|       S|         0|              1|
# |        830|       1|     1|Stone, Mrs. Georg...|female|62.0|    0|    0|113572|80.0|  B28|       S|         0|              1|
# +-----------+--------+------+--------------------+------+----+-----+-----+------+----+-----+--------+----------+---------------+

# %% [markdown]
# # Visualize Data

# %%
pd_df = dt_df_nnae.toPandas()

# %%
pd_df.plot(kind='box',subplots=True, sharex=False, sharey=False, layout=(2,4), figsize=(20,10))
# Out:
# PassengerId           AxesSubplot(0.125,0.536818;0.168478x0.343182)
# Survived           AxesSubplot(0.327174,0.536818;0.168478x0.343182)
# Pclass             AxesSubplot(0.529348,0.536818;0.168478x0.343182)
# Age                AxesSubplot(0.731522,0.536818;0.168478x0.343182)
# SibSp                    AxesSubplot(0.125,0.125;0.168478x0.343182)
# Parch                 AxesSubplot(0.327174,0.125;0.168478x0.343182)
# Fare                  AxesSubplot(0.529348,0.125;0.168478x0.343182)
# embarkedImputed       AxesSubplot(0.731522,0.125;0.168478x0.343182)
# dtype: object

# %%
sns.pairplot(pd_df, hue='Survived')
# Out:
# /opt/venv/lib/python3.7/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)

# %%
sns.set(style="white") 
plt.rcParams['figure.figsize'] = (15, 10) 
sns.heatmap(pd_df.corr(), annot = True, linewidths=.5, cmap="Blues")
plt.show()

# %% [markdown]
# ### Build ML Pipeline

# %%
from pyspark.ml.feature import StringIndexer

# %%
# dt_df_nnae.select('*').show(5)

# %%
ml_df = dt_df_nnae.select( "Pclass", "Sex", "Age", "SibSp", 'Parch', 'Fare', 'Embarked', "Survived")
# Out:
# +------+------+----+-----+-----+-------+--------+--------+
# |Pclass|   Sex| Age|SibSp|Parch|   Fare|Embarked|Survived|
# +------+------+----+-----+-----+-------+--------+--------+
# |     3|  male|28.0|    0|    0|   7.05|       S|       0|
# |     2|  male|32.0|    2|    0|   73.5|       S|       0|
# |     3|  male|18.0|    0|    0| 7.7958|       S|       0|
# |     3|  male|42.0|    0|    0|   7.55|       S|       0|
# |     2|female| 5.0|    1|    2|  27.75|       S|       1|
# |     2|female|34.0|    0|    1|   23.0|       S|       1|
# |     1|female|25.0|    1|    2| 151.55|       S|       0|
# |     2|  male|25.0|    1|    2|41.5792|       C|       0|
# |     3|female| 4.0|    1|    1|   16.7|       S|       1|
# |     2|  male|32.0|    0|    0|   10.5|       S|       0|
# |     2|  male|36.0|    0|    0|   10.5|       S|       0|
# |     3|  male|65.0|    0|    0|   7.75|       Q|       0|
# |     3|  male|38.0|    0|    0| 8.6625|       S|       0|
# |     3|  male|35.0|    0|    0|   8.05|       S|       0|
# |     1|female|18.0|    1|    0|227.525|       C|       1|
# |     2|  male|39.0|    0|    0|   26.0|       S|       0|
# |     3|  male|30.0|    0|    0|   8.05|       S|       0|
# |     3|  male|40.0|    1|    1|   15.5|       Q|       0|
# |     2|  male|36.0|    0|    0|   13.0|       S|       0|
# |     2|  male|46.0|    0|    0|   26.0|       S|       0|
# +------+------+----+-----+-----+-------+--------+--------+
# only showing top 20 rows

# %%
sindexer=StringIndexer(inputCols=["Sex","Embarked"], outputCols=['SexIndexed','EmbarkedIndexed'])

# %%
sindexer_model = sindexer.fit(ml_df)
sml_df = sindexer_model.transform(ml_df)
# sml_df.show()

# %%
from pyspark.ml.feature import OneHotEncoder

# %%
ohe = OneHotEncoder(inputCols=['SexIndexed','EmbarkedIndexed','Pclass'], outputCols=['SexOHE','EmbarkedOHE','PclassOHE'])

# %%
ohe_model = ohe.fit(sml_df)
osml_df = ohe_model.transform(sml_df)
# osml_df.show()

# %%
from pyspark.ml.feature import VectorAssembler

# %%
vecAssembler = VectorAssembler(inputCols=['Age','Fare','SexOHE','EmbarkedOHE','PclassOHE'], outputCol='features')

# %%
vosml_df = vecAssembler.transform(osml_df)
# vosml_df.show()

# %%
from pyspark.ml.classification import RandomForestClassifier

# %%
final_df = vosml_df.select('features','survived')

# %%
rf_classifier = RandomForestClassifier(featuresCol='features',labelCol='survived')

# %%
rf_predictions = rf_classifier.fit(final_df)
rf_predictions_model
# Out:
# RandomForestClassificationModel: uid=RandomForestClassifier_1b4e631f6d57, numTrees=20, numClasses=2, numFeatures=8

# %%
from pyspark.ml import Pipeline
pipeline = Pipeline(stages=[sindexer_model, ohe_model, vecAssembler, rf_predictions_model])
pipelineModel = pipeline.fit(test_df)

# %%
from pyspark.ml.evaluation import MulticlassClassificationEvaluator

# %%
print('Accuracy: ', MulticlassClassificationEvaluator(labelCol='survived',metricName='accuracy').evaluate(rf_predictions))
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-128-a5ebf6435308> in <module>
# ----> 1 print('Accuracy: ', MulticlassClassificationEvaluator(labelCol='survived',metricName='accuracy').evaluate(rf_predictions))
#
# NameError: name 'rf_predictions' is not defined

# %%
print('Precision: ',MulticlassClassificationEvaluator(labelCol='survived',metricName='weightedPrecision').evaluate(rf_predictions))
